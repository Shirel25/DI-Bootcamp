# %%
import numpy as np
import random
import pandas as pd

# %% [markdown]
# 1. **Data Preparation:**

# %%
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
cities = ['city 1', 'city 2', 'city 3', 'city 4', 'city 5', 'city 6', 'city 7', 'city 8', 'city 9', 'city 10']

# %%
# Set a random seed for reproducibility
np.random.seed(42)

data = np.round(np.random.uniform(-5, 35, size=(10,12)), 2)

# %%
print(data)
# Out:
# [[ 9.98 33.03 24.28 18.95  1.24  1.24 -2.68 29.65 19.04 23.32 -4.18 33.8 ]
#  [28.3   3.49  2.27  2.34  7.17 15.99 12.28  6.65 19.47  0.58  6.69  9.65]
#  [13.24 26.41  2.99 15.57 18.7  -3.14 19.3   1.82 -2.4  32.96 33.63 27.34]
#  [ 7.18 -1.09 22.37 12.61 -0.12 14.81 -3.62 31.37  5.35 21.5   7.47 15.8 ]
#  [16.87  2.39 33.78 26.01 32.58 30.79 18.92 31.87 -1.46  2.84 -3.19  8.01]
#  [10.55  5.85 28.15  9.27  6.24 16.71  0.64 27.09 -2.02 34.48 25.89  2.95]
#  [-4.78 27.62 23.27 24.16 25.85 -2.04  9.34 -0.37 29.52 19.93  8.24 -2.46]
#  [ 7.44  8.01 24.18 20.5  30.49 13.89 -0.22 23.53 25.43 17.45 25.84 14.75]
#  [15.91 12.1  -3.98 -0.68 -3.74 20.46  7.57 15.34 31.3   4.97 11.42 25.22]
#  [ 4.15 -1.92  6.59  1.45 32.19 27.32 20.34 29.86 27.15  2.46 30.7  16.57]]

# %%
dataset = pd.DataFrame(data, index=cities, columns=months)
print(dataset)
# Out:
#            Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep    Oct  \
# city 1    9.98  33.03  24.28  18.95   1.24   1.24  -2.68  29.65  19.04  23.32
# city 2   28.30   3.49   2.27   2.34   7.17  15.99  12.28   6.65  19.47   0.58
# city 3   13.24  26.41   2.99  15.57  18.70  -3.14  19.30   1.82  -2.40  32.96
# city 4    7.18  -1.09  22.37  12.61  -0.12  14.81  -3.62  31.37   5.35  21.50
# city 5   16.87   2.39  33.78  26.01  32.58  30.79  18.92  31.87  -1.46   2.84
# city 6   10.55   5.85  28.15   9.27   6.24  16.71   0.64  27.09  -2.02  34.48
# city 7   -4.78  27.62  23.27  24.16  25.85  -2.04   9.34  -0.37  29.52  19.93
# city 8    7.44   8.01  24.18  20.50  30.49  13.89  -0.22  23.53  25.43  17.45
# city 9   15.91  12.10  -3.98  -0.68  -3.74  20.46   7.57  15.34  31.30   4.97
# city 10   4.15  -1.92   6.59   1.45  32.19  27.32  20.34  29.86  27.15   2.46
#
#            Nov    Dec
# city 1   -4.18  33.80
# city 2    6.69   9.65
# city 3   33.63  27.34
# ...

# %% [markdown]
# 2. **Data Analysis:**

# %%
# avg per month
avg_temp_month = dataset.mean(axis=0)
print(avg_temp_month)
# Out:
# Jan    10.884
# Feb    11.589
# Mar    16.390
# Apr    13.018
# May    15.060
# Jun    13.603
# Jul     8.187
# Aug    19.681
# Sep    15.138
# Oct    16.049
# Nov    14.251
# Dec    15.163
# dtype: float64

# %%
# avg per city
avg_temp_city = dataset.mean(axis=1)
print(avg_temp_city)
# Out:
# city 1     15.639167
# city 2      9.573333
# city 3     15.535000
# city 4     11.135833
# city 5     16.617500
# city 6     13.816667
# city 7     13.190000
# city 8     17.607500
# city 9     11.324167
# city 10    16.405000
# dtype: float64

# %%
# annual avg
avg_year = avg_temp_city.mean()
print(avg_year)
# Out:
# 14.084416666666666

# %%
highest_temp_city = avg_temp_city.idxmax()
print(highest_temp_city)
# Out:
# city 8

# %%
lowest_temp_city = avg_temp_city.idxmin()
print(lowest_temp_city)
# Out:
# city 2

# %% [markdown]
# 3. **Data Visualization:**

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 6))

for city in cities:
    plt.plot(dataset.columns, dataset.loc[city], label=city, linestyle=random.choice(['-', '--', '-.', ':']))

plt.xlabel('Month', fontsize=12)
plt.ylabel('Temperature (°C)', fontsize=12)
plt.title('Monthly Temperature Trends for Each City', fontsize=14)
plt.legend(title="City", loc='lower left')

plt.show()
